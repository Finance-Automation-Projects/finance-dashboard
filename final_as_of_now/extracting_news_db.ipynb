# %%
import interface

# %%
obj = interface.NewsDatabase()

# %%
a,b= obj.to_dataframe()

# %%
a
# Out:
#                                                   title  \
# 0     Top Gainers and Losers today on 6 December, 20...
# 1     Adani Group plans to invest $2 bn for acquisit...
# 2     Adani Enterprises, Adani Ports and other Adani...
# 3     Adani Ports SEZ Share Price Live Updates: Adan...
# 4     Amid bribery lens, Adani makes move to develop...
# ...                                                 ...
# 6093  Wealthtime pioneers innovative business transf...
# 6094  Stock Radar: Swiggy, Wipro, Indegene, Protean ...
# 6095  Upcoming corporate actions: Wipro to give bonu...
# 6096  Wipro, Eraaya Lifespaces and Can Fin Homes amo...
# 6097  Stocks To Watch: PB Fintech, Swiggy, Wipro, HU...
#
#                                                     url  \
# 0     https://news.google.com/rss/articles/CBMiygJBV...
# 1     https://news.google.com/rss/articles/CBMivwFBV...
# 2     https://news.google.com/rss/articles/CBMi6gFBV...
# 3     https://news.google.com/rss/articles/CBMiwwFBV...
# ...

# %%
b
# Out:
#     Earnings   Revenue   Margins  Dividend    EBITDA      Debt  Sentiment  \
# 0   0.494385  0.526065  0.338105  0.510702  0.499993  0.283205   0.525589
# 1   0.754787  0.756658  0.680362  0.709297  0.759259  0.516974   0.701649
# 2  -0.494166 -0.419712 -0.468254 -0.309077 -0.363647 -0.497203  -0.818239
# 3   0.602679  0.518134  0.328755  0.530359  0.463490  0.229215   0.353485
# 4   0.301785  0.362814  0.285041  0.316887  0.378003  0.068461  -0.011378
# 5   0.322325  0.407156  0.185373  0.454213  0.305887 -0.167935   0.304311
# 6   0.529305  0.494560  0.354685  0.483931  0.490922  0.015231   0.357276
# 7   0.468764  0.456750  0.338916  0.527841  0.448351  0.173500   0.546222
# 8   0.175088  0.261727  0.017002  0.378091  0.122129 -0.205294  -0.025017
# 9  -0.183614  0.115372 -0.210957  0.184437 -0.153262 -0.375296  -0.315189
# 10  0.577385  0.356962  0.297170  0.533094  0.480961 -0.002790   0.137496
# 11  0.038587 -0.125600  0.025794  0.267707 -0.109716 -0.568386   0.153695
# ...
